# %% [markdown]
# # Requirements

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from jsonschema.exceptions import best_match
from sklearn import metrics
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBClassifier, XGBRegressor
from sklearn.impute import SimpleImputer
from sklearn.impute import KNNImputer
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder, OneHotEncoder
from sklearn.tree import DecisionTreeClassifier,DecisionTreeRegressor
from sklearn.model_selection import train_test_split, KFold, GridSearchCV
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import f1_score, classification_report, confusion_matrix, mean_squared_error, mean_absolute_error,r2_score

# %% [markdown]
# # Laboratory Exercise - Run Mode (8 points)

# %% [markdown]
# ## Introduction
# In this laboratory assignment, the focus is on time series forecasting, specifically targeting the prediction of the current **average sea-level pressure** in the city of Skopje. Your task involves employing bagging and boosting methods to forecast the average sea-level pressure. To accomplish this, you will use data from the preceding three days, consisting of average, minimal, and maximal temperatures, precipitation, as well as wind direction and speed, and the current season. By applying these ensemble learning techniques, you aim to enhance the accuracy and reliability of your predictions, gaining valuable insights into the temporal dynamics of sea-level pressure based on the given meteorological variables.
#
# **Note: You are required to perform this laboratory assignment on your local machine.**

# %% [markdown]
# ## The Weather Dataset

# %% [markdown]
# ## Exploring the Weather Dataset
# This dataset consists of daily weather records for the city of Skopje from January 1, 2021, to August 1, 2023. Each entry includes a unique station ID, city name, date, corresponding season (e.g., summer, winter), and various meteorological parameters such as average, minimum, and maximum temperatures in Celsius, precipitation in millimeters, average wind direction in degrees, average wind speed in kilometers per hour, and average sea-level pressure in hectopascals. The dataset offers comprehensive insights into the climatic conditions, allowing for analysis and exploration of weather patterns in Skopje over the specified time period.
#
# The dataset comprises the following columns:
# - station_id - unique ID for the weather station,
# - city_name - name of the city where the station is located,
# - date - date of the weather record,
# - season - season corresponding to the date (e.g., summer, winter),
# - avg_temp_c - average temperature in Celsius,
# - min_temp_c - minimum temperature in Celsius,
# - max_temp_c - maximum temperature in Celsius,
# - precipitation_mm - precipitation in millimeters,
# - avg_wind_dir_deg - average wind direction in degrees,
# - avg_wind_speed_kmh - average wind speed in kilometers per hour, and
# - avg_sea_level_pres_hpa - average sea-level pressure in hectopascals.
#
# *Note: The dataset is complete, with no missing values in any of its entries.*

# %% [markdown]
# Load the dataset into a `pandas` data frame.

# %%
df = pd.read_csv('weather.csv')

# %%
df.head()
# Out:
#    station_id city_name        date  season  avg_temp_c  min_temp_c  \
# 0       13588    Skopje  2021-01-01  Winter         5.1         0.5
# 1       13588    Skopje  2021-01-02  Winter         3.0        -2.6
# 2       13588    Skopje  2021-01-03  Winter         6.8         3.5
# 3       13588    Skopje  2021-01-04  Winter         6.6         6.1
# 4       13588    Skopje  2021-01-05  Winter         4.3         2.3
#
#    max_temp_c  precipitation_mm  avg_wind_dir_deg  avg_wind_speed_kmh  \
# 0        13.2               0.0             330.0                 5.9
# 1        11.2               0.0             330.0                 5.9
# 2        12.5               1.3             339.0                 8.0
# 3         7.2               3.6             298.0                 5.3
# 4         6.7               4.6              11.0                 5.1
#
#    avg_sea_level_pres_hpa
# 0                  1021.2
# 1                  1021.2
# 2                  1017.8
# 3                  1011.3
# 4                  1014.5

# %%
df.info()
df['date'] = pd.to_datetime(df['date'])
df = df.sort_values(by='date')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 943 entries, 0 to 942
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   station_id              943 non-null    int64
#  1   city_name               943 non-null    object
#  2   date                    943 non-null    object
#  3   season                  943 non-null    object
#  4   avg_temp_c              943 non-null    float64
#  5   min_temp_c              943 non-null    float64
#  6   max_temp_c              943 non-null    float64
#  7   precipitation_mm        943 non-null    float64
#  8   avg_wind_dir_deg        943 non-null    float64
#  9   avg_wind_speed_kmh      943 non-null    float64
#  10  avg_sea_level_pres_hpa  943 non-null    float64
# dtypes: float64(7), int64(1), object(3)
# memory usage: 81.2+ KB

# %%
df.head(20)
# Out:
#     station_id city_name       date  season  avg_temp_c  min_temp_c  \
# 0        13588    Skopje 2021-01-01  Winter         5.1         0.5
# 1        13588    Skopje 2021-01-02  Winter         3.0        -2.6
# 2        13588    Skopje 2021-01-03  Winter         6.8         3.5
# 3        13588    Skopje 2021-01-04  Winter         6.6         6.1
# 4        13588    Skopje 2021-01-05  Winter         4.3         2.3
# 5        13588    Skopje 2021-01-06  Winter         6.2         2.6
# 6        13588    Skopje 2021-01-07  Winter         7.3         4.1
# 7        13588    Skopje 2021-01-08  Winter         5.7         4.2
# 8        13588    Skopje 2021-01-09  Winter         2.9         1.5
# 9        13588    Skopje 2021-01-10  Winter         2.2         1.3
# 10       13588    Skopje 2021-01-11  Winter         3.3         2.1
# 11       13588    Skopje 2021-01-12  Winter         2.4        -1.3
# 12       13588    Skopje 2021-01-13  Winter         2.1        -1.1
# 13       13588    Skopje 2021-01-14  Winter        -1.1        -4.0
# 14       13588    Skopje 2021-01-15  Winter        -2.6        -6.7
# 15       13588    Skopje 2021-01-16  Winter        -1.6        -6.2
# 16       13588    Skopje 2021-01-17  Winter        -1.9        -7.1
# 17       13588    Skopje 2021-01-18  Winter        -2.5        -4.5
# 18       13588    Skopje 2021-01-19  Winter        -3.3        -8.5
# 19       13588    Skopje 2021-01-20  Winter        -1.6        -7.4
#
#     max_temp_c  precipitation_mm  avg_wind_dir_deg  avg_wind_speed_kmh  \
# 0         13.2               0.0             330.0                 5.9
# 1         11.2               0.0             330.0                 5.9
# 2         12.5               1.3             339.0                 8.0
# 3          7.2               3.6             298.0                 5.3
# 4          6.7               4.6              11.0                 5.1
# 5         11.0               0.0              18.0                 6.7
# 6          9.3               0.5               0.0                 4.5
# 7          8.1               7.9             346.0                 6.5
# 8          5.4               8.1             300.0                 5.9
# 9          3.1               6.1             354.0                 4.7
# 10         5.0              26.2             338.0                 6.7
# 11         5.6               0.8             293.0                 5.8
# 12         7.6               0.0             294.0                 6.0
# 13         0.7               0.0             224.0                 6.3
# 14         2.3               0.0             233.0                 5.5
# 15         1.4               0.0             290.0                 7.7
# 16         2.0               0.4             207.0                 4.6
# 17         2.1               0.0             258.0                 4.4
# 18         3.7               0.0             261.0                 4.8
# 19         5.3               0.0              24.0                 5.9
#
#     avg_sea_level_pres_hpa
# 0                   1021.2
# 1                   1021.2
# 2                   1017.8
# 3                   1011.3
# 4                   1014.5
# 5                   1017.2
# 6                   1015.2
# 7                   1009.7
# 8                   1016.8
# 9                   1017.1
# 10                  1014.2
# 11                  1013.5
# 12                  1012.5
# 13                  1013.2
# 14                  1017.4
# 15                  1018.0
# 16                  1018.6
# 17                  1023.7
# 18                  1027.3
# 19                  1027.5

# %%
for col in df.columns:
    print(f"{str(col)} -  {df[col].unique()}")
# Out:
# station_id -  [13588]
# city_name -  ['Skopje']
# date -  <DatetimeArray>
# ['2021-01-01 00:00:00', '2021-01-02 00:00:00', '2021-01-03 00:00:00',
#  '2021-01-04 00:00:00', '2021-01-05 00:00:00', '2021-01-06 00:00:00',
#  '2021-01-07 00:00:00', '2021-01-08 00:00:00', '2021-01-09 00:00:00',
#  '2021-01-10 00:00:00',
#  ...
#  '2023-07-23 00:00:00', '2023-07-24 00:00:00', '2023-07-25 00:00:00',
#  '2023-07-26 00:00:00', '2023-07-27 00:00:00', '2023-07-28 00:00:00',
#  '2023-07-29 00:00:00', '2023-07-30 00:00:00', '2023-07-31 00:00:00',
#  '2023-08-01 00:00:00']
# Length: 943, dtype: datetime64[ns]
# season -  ['Winter' 'Spring' 'Summer' 'Autumn']
# avg_temp_c -  [ 5.1  3.   6.8  6.6  4.3  6.2  7.3  5.7  2.9  2.2  3.3  2.4  2.1 -1.1
#  -2.6 -1.6 -1.9 -2.5 -3.3  1.7  6.7  5.3  8.8  3.6  1.2  0.4  7.2  5.6
#   6.9  8.   7.6  7.9  8.1  6.1  7.8  5.2 -2.8 -5.9 -6.1  2.8  6.4  4.
#   6.   8.4 12.1 13.1 12.5 12.9 11.4 10.1  8.5  4.9 14.3  7.7  3.7  3.9
#   3.5  4.2  6.5  2.6  0.9  0.3 10.5 12.3 11.8 15.3 14.6  5.4  9.3 10.2
#   4.5  8.7 11.6 13.9 13.7  7.4  9.5  6.3  8.9 10.3 10.9 10.6 12.4 14.
#  14.7 17.8 16.1 18.6 21.3 18.1 23.4 18.8 18.4 19.7 15.7 15.2 17.4 20.7
#  17.9 16.9 17.5 19.2 16.4 16.2 21.7 23.2 24.3 21.4 20.8 15.5 19.3 18.9
#  19.5 20.3 19.4 21.9 22.7 20.6 19.9 19.6 17.3 18.3 21.8 24.8 30.8 29.2
#  32.5 30.5 28.3 25.2 28.6 29.4 31.2 24.7 23.7 26.2 25.3 28.8 28.2 29.5
#  29.9 25.9 25.7 28.1 30.3 27.4 23.6 22.4 24.2 23.9 25.1 25.5 27.1 27.9
#  27.2 29.6 28.7 30.4 29.8 27.7 25.6 30.2 29.3 26.9 26.8 27.6 21.  24.5
#  24.6 21.5 22.  20.4 20.9 19.1 19.8 20.2 24.4 15.8 13.  18.5 15.  14.4
#  12.7 15.6 17.7 11.9 12.2  9.  10.8  9.8  7.   9.1 12.  14.8 11.  12.6
#   8.3  8.2  9.4  9.2  9.9 13.4 15.9 13.2  5.   2.3  7.1  3.2  2.7  1.1
#  -1.7 -2.1  1.   4.6  7.5  5.8  3.8  4.4  4.1  5.5  1.4 -0.1  0.7 -0.5
#   3.1  0.8 -2.2 -3.4 -4.2  0.   1.5  5.9  1.6  1.3 -0.2  3.4 13.3 11.7
#  11.5  9.6 14.9 14.1 16.  17.6 16.5 11.2 15.1 16.8 17.2 17.1 21.1 20.5
#  25.  20.1 21.6 19.  25.8 28.9 25.4 23.3 26.6 21.2 22.8 23.5 26.4 23.8
#  26.5 26.1 23.1 26.7 26.3 23.  27.3 27.8 27.  28.  24.  24.9 22.2 24.1
#  20.  22.3 15.4 18.2 12.8 13.6 16.3 10.7 14.2 13.5 10.4  8.6  9.7  1.8
#   2.   0.5 -0.6  1.9  4.7  4.8  2.5 -2.3 13.8 11.1 16.7 28.5 30.6]
# min_temp_c -  [  0.5   -2.6    3.5    6.1    2.3    2.6    4.1    4.2    1.5    1.3
#    2.1   -1.3   -1.1   -4.    -6.7   -6.2   -7.1   -4.5   -8.5   -7.4
#   -4.6   -1.6    0.6    3.9   -1.   -11.7   -2.8    2.4    1.4    2.5
#    3.8    1.6    1.     4.5    1.9   -0.7   -7.6   -8.4   -6.1  -14.2
#  -10.9   -1.5   -2.2   -1.4    0.3    1.2    2.8    3.2    5.    -2.1
#   -1.9    1.8    3.1   -0.9   -4.8    0.9   -0.1   -2.     0.8    4.
#    3.3    4.4   -2.5   -0.5   -4.4    5.9    8.1    5.6    8.6    5.1
#    7.8    1.1   -2.9    2.     7.1   10.6    5.8    3.     5.3    5.7
#    9.1    9.7    6.4    5.5    8.5    8.3    8.    13.4   13.3   13.6
#   12.8    8.7   10.4    9.9   10.7   10.8   11.7   12.3   14.2    7.2
#   17.1   15.4   15.8   11.8    8.9   11.4   11.6   13.5   14.    16.4
#   12.9   14.9   13.8   14.5   12.7   16.1   15.7   18.7   16.6   18.2
#   18.1   19.8   21.3   21.9   20.4   19.    19.5   20.6   20.8   18.5
#   17.4   20.1   21.5   18.6   21.1   19.9   22.7   21.8   19.1   19.4
#   17.    14.8   16.9   16.    20.3   20.2   21.4   20.5   21.    16.7
#   18.    22.3   20.7   18.9   20.    17.3   16.8   15.2   17.6   17.2
#   13.9   13.7   13.1   12.4   12.2   14.1   14.3   12.    14.4   15.
#   15.1    9.    10.9   12.5    6.5    7.     7.4   11.3    7.5    6.3
#    3.7    5.2    9.4    9.2    4.3    1.7    6.     9.8   12.6    9.6
#    4.8    2.7    7.7    6.7   -1.2  -13.5   -1.7   -3.4   -4.9   -6.
#   -6.4   -6.6    0.2   -0.3   -6.5   -6.8   -5.1   -5.8   -4.1   -7.3
#   -8.3   -9.    -0.6   -3.9   -0.2   -2.4    0.1    2.2   -0.8   -3.
#    0.    -2.7   -3.8    2.9    6.2    5.4    3.6    9.3    7.3    9.5
#    7.6   11.1   10.5    8.8    6.9   14.6   15.6   16.75  17.9   17.8
#   18.4   13.2   17.5   17.7   16.3   21.2   19.7   15.3   22.2   18.3
#   15.5   18.8   22.    16.5   19.2   19.6   10.    11.5   10.1    6.6
#    8.4   13.     4.9    6.8    7.9    8.2    4.7   -0.4    4.6    0.7
#   -3.7   -4.7   -7.    -5.9   -3.6   10.3   10.2   12.1   11.2   15.9
#   16.2   21.6   22.5   22.9   20.9 ]
# max_temp_c -  [13.2 11.2 12.5  7.2  6.7 11.   9.3  8.1  5.4  3.1  5.   5.6  7.6  0.7
#   2.3  1.4  2.   2.1  3.7  5.3  8.   8.4 10.8  9.7 13.3 10.7  4.2  6.4
#   9.4 15.5 11.1 11.8 14.3 15.6 17.3 16.1 15.7 12.1 12.7 13.8 10.2 -4.4
#  -3.1  2.6 10.6  4.3 12.2  9.1 10.1 12.8 16.4 21.2 19.4 20.5 20.6 20.7
#  14.6 15.  19.6 13.1 13.4  6.5  6.9  7.8  5.8  8.2 10.5 12.6 10.   9.2
#   5.1  3.6  2.7  6.8  8.8 13.9 18.3 21.1 18.4 19.5 22.7 22.1 21.4 13.6
#  18.2 14.2 18.7 23.1 20.  14.4 14.5  7.7 15.1 12.3 17.1 13.7 24.1 24.7
#  27.1 29.4 25.1 31.6 26.  25.8 24.2 20.9 26.2 28.7 26.5 23.  23.7 19.2
#  25.6 25.  19.9 22.6 27.2 30.6 31.9 32.2 28.2 28.8 25.2 20.1 22.2 24.6
#  30.4 28.  30.  26.8 27.  27.8 21.7 31.3 31.1 32.1 36.  39.3 39.6 39.7
#  38.9 35.1 36.5 38.5 39.4 39.  29.1 31.2 32.6 33.9 37.2 38.  38.1 33.3
#  33.7 37.1 38.6 36.8 37.3 31.4 27.5 27.4 29.9 31.5 34.1 39.1 40.9 40.3
#  41.2 39.2 40.7 40.6 32.3 33.5 38.3 39.8 38.4 36.6 35.3 32.4 33.6 32.
#  24.5 29.2 30.9 28.5 30.5 25.7 26.9 28.9 27.9 23.3 25.4 29.8 31.7 31.8
#  24.4 27.6 29.  23.2 20.4 26.3 23.4 17.2 18.9 21.9 22.5 14.1 10.3 14.8
#  14.   7.3  9.  11.7 15.8 18.5 17.7 16.9 18.8 16.7 17.9 16.8 17.8 19.
#  15.3 11.4  9.8 15.9  5.2  8.9  8.7  3.4  3.8  4.   4.7  6.  10.9  7.
#   5.9  3.3  3.5  7.9 16.6  6.3  7.5  4.5  0.6  1.6  2.8  1.5 -1.   3.9
#   6.6  9.9  2.2  7.4 11.9 13.5 11.5 16.2  3.   4.8  6.2  7.1 12.4 12.
#  17.4 21.6 22.8 16.3 23.6 19.1 24.8 21.8 20.8 26.6 26.1 21.  22.9 22.3
#  30.7 30.2 30.1 24.3 32.5 32.7 27.7 34.9 36.7 33.  21.3 25.5 29.7 28.3
#  26.7 34.5 33.4 35.8 31.  34.8 17.  26.4 27.3 35.5 34.4 38.2 34.3 36.2
#  33.1 30.8 37.  29.5 33.2 30.3 28.4 24.  20.3 25.3 18.  22.  24.9 16.5
#  20.2 18.6 18.1 11.3  9.5  2.9 10.4  8.3  8.5 11.6  8.6  0.4  0.1  6.1
#  15.2 14.7 15.4 19.8 19.3 17.5 23.8 34.  29.3 37.7 38.8 36.9 35.4 36.4]
# precipitation_mm -  [ 0.   1.3  3.6  4.6  0.5  7.9  8.1  6.1 26.2  0.8  0.4  6.6  0.3  3.3
#   7.1  8.9  6.4  0.1  2.1  0.7  8.   4.2  7.2 28.2  5.6  2.8 11.9  2.
#   5.1  1.1  1.   4.1  9.7 11.2  4.3 13.7  3.1  0.2 11.7  1.5  7.4 39.4
#   2.5 18.8 10.9 20.1  7.6  9.4  6.7 14.5  6.9 16.   0.6  5.8 12.2  6.5
#  17.2  9.3 12.7 11.1 22.6  5.3  9.1 15.5  1.9  4.  15.8 32.5  1.8  3.7
#   4.8  2.3  1.4 17.8 21.6  2.4 10.4 10.6  6.8  2.6  9.   0.9  3.2  2.9
#   3.   2.2 13.  15.  13.2  9.6 12.4  3.8]
# avg_wind_dir_deg -  [330.  339.  298.   11.   18.    0.  346.  300.  354.  338.  293.  294.
#  224.  233.  290.  207.  258.  261.   24.   15.    7.   44.  304.  315.
#  284.  254.   43.  295.   30.  336.  324.  350.  332.  341.   16.  348.
#  169.  301.  286.  281.  242.  282.  262.  326.   52.    9.  321.  249.
#  271.  248.  323.  292.  285.  259.  320.  333.  287.    2.  280.  305.
#   99.  137.  272.  288.  252.  307.5 275.  256.  277.  276.   21.  342.
#  310.  264.  219.   81.   45.  190.  223.  212.  303.  253.   56.   62.
#   41.   40.   70.   17.  231.  283.  157.   82.   68.   79.  268.  273.
#  257.  267.  270.  279.  174.  132.   58.  306.  299.  307.  296.  203.
#  265.  291.  319.  316.  247.    8.   83.  234.  274.  221.    6.  313.
#  312.  213.   57.  246.  179.   71.  250.  302.  309.  236.  311.  269.
#  241.  232.   60.   34.  230.  239.  263.  255.  245.  278.  356.  297.
#  314.  266.   38.  347.   49.   87.   28.   32.  260.  349.  352.  343.
#  325.  334.  340.  355.    5.   14.    3.  329.   12.   26.  335.  344.
#   27.   48.   22.   29.   25.  359.  243.  244.  289.    1.  337.  122.
#  228.   13.  317.  208.  205.   92.  131.  245.5 121.   47.   51.  308.
#   72.  220.   76.   59.  357.  227.   20.  235.  238.   46.  155.  148.
#  237.  222.  109.   36.  226.  215.   66.  229.  216.   31.   63.  328.
#   69.  358.  331.   50.  152.  327.   19.   10.   33.   23.  353.  143.
#   96.   91.  139.   94.  106.  200.  218.  195.  177.  104.  118.   78.
#   39.  156.  115.  153.  127.  159.  145.   73.   89.  161.  111.  125.
#   86.   88.  182.  105.   37. ]
# avg_wind_speed_kmh -  [ 5.9   8.    5.3   5.1   6.7   4.5   6.5   4.7   5.8   6.    6.3   5.5
#   7.7   4.6   4.4   4.8   7.2   7.    7.6   8.3  11.1  12.5   7.8   7.3
#   6.6   5.    4.1   6.8   7.9   3.2   9.7   8.5   3.8   4.2   4.9   4.3
#   7.1   4.    5.7   6.2   8.9  13.8  13.5   2.2   2.4  11.3  11.2   6.1
#   6.05  8.1   8.8   3.6   3.9   9.8   9.    6.4   7.4  10.1   5.2   7.5
#   5.6   8.2   8.4   9.6   9.9   5.4   6.9  10.3   9.2   3.7  11.6  10.2
#   3.4  10.9  11.7  10.5   9.4  10.6   9.1  13.2   8.7   3.5  10.4  10.7
#  11.9   5.25 10.   11.4  14.7   9.3   9.5   2.5   2.9   2.7   3.    2.8
#  11.8  19.1  16.5  12.3  16.7  13.7   8.35 24.9  16.1  28.8  14.9  11.
#   8.6  13.1  12.7  14.4  15.9  12.2  12.6  13.4  16.  ]
# avg_sea_level_pres_hpa -  [1021.2  1017.8  1011.3  1014.5  1017.2  1015.2  1009.7  1016.8  1017.1
#  1014.2  1013.5  1012.5  1013.2  1017.4  1018.   1018.6  1023.7  1027.3
#  1027.5  1025.7  1020.4  1010.5  1004.9  1003.3  1007.4  1012.8  1010.2
#  1003.5  1002.7  1012.1  1017.5  1018.4  1020.3  1016.9  1011.6  1002.5
#  1008.4  1009.2  1025.4  1030.   1030.5  1033.8  1029.6  1024.2  1023.
#  1027.1  1027.2  1030.8  1031.9  1032.3  1034.7  1028.3  1023.1  1030.1
#  1033.7  1031.3  1023.6  1017.9  1025.8  1027.   1018.8  1021.6  1019.9
#  1016.7  1011.   1002.   1005.5  1009.8  1014.4  1011.8  1005.6  1015.
#  1022.1  1025.9  1027.7  1029.65 1031.6  1028.8  1025.   1018.5  1011.2
#  1015.6  1015.5  1005.3  1008.1  1022.9  1029.   1021.1  1016.1  1015.7
#  1019.8  1020.   1016.5  1013.7  1020.6  1021.8  1021.7  1015.9  1010.3
#  1012.2  1013.6  1010.7  1015.1  1010.9  1013.1  1017.   1020.7  1014.7
#  1008.6  1010.6  1009.4  1007.7  1010.8  1010.4  1019.2  1016.3  1015.4
#  1012.4  1016.2  1014.9  1018.9  1023.3  1016.6  1016.4  1014.8  1014.3
#  1015.8  1016.   1011.9  1014.6  1013.8  1009.1  1012.3  1014.1  1013.9
#  1012.6  1012.9  1009.6  1006.7  1006.   1017.3  1013.3  1010.1  1008.3
#  1017.6  1020.5  1009.5  1010.   1007.8  1020.2  1020.9  1022.2  1019.
#  1017.7  1021.5  1019.4  1021.   1019.5  1022.5  1023.9  1022.8  1022.7
#  1023.4  1020.8  1023.5  1028.5  1028.2  1020.1  1029.4  1029.5  1025.6
#  1026.4  1024.   1022.3  1026.   1028.6  1023.8  1025.1  1024.7  1008.5
#   997.9  1011.4  1009.9  1006.1  1006.9  1028.   1028.7  1025.2  1026.2
#  1012.   1019.3  1014.   1005.   1004.3  1036.6  1029.2  1024.5  1029.7
#  1032.9  1024.4  1022.4  1026.5  1031.   1032.6  1006.6  1019.7  1029.3
#  1028.9  1024.3  1018.1  1021.4  1019.6  1027.8  1030.3  1034.2  1034.4
#  1035.4  1037.5  1038.   1034.6  1030.6  1026.3  1025.3  1003.2   998.7
#  1003.   1012.7  1004.   1006.3  1026.8  1015.95 1011.1  1013.4  1007.
#  1018.2  1013.   1015.3  1021.3  1011.7  1008.9  1009.   1008.   1009.3
#  1004.1  1005.4  1007.6  1027.9  1023.2  1019.1  1030.4  1024.8  1021.9
#  1026.9  1030.7  1004.2  1008.8  1007.9  1007.5  1003.8  1022.   1025.5
#  1005.7   998.3  1037.2  1034.   1026.1  1032.4  1033.2  1002.8  1004.7
#  1018.3  1024.1  1030.9  1035.6  1039.   1039.1  1037.3  1035.1  1037.1
#  1032.8  1032.5  1031.2  1024.6  1000.6  1005.9  1007.05 1002.9  1022.6
#  1008.7  1011.5  1018.7 ]

# %%
sns.pairplot(df)

# %% [markdown]
# Explore the dataset using visualizations of your choice.

# %%
encoder = OrdinalEncoder()
for column in df.columns:
    if type(df[column][0]) == str:
        df[[column]] = encoder.fit_transform(df[[column]])
df.head()
# Out:
#    station_id  city_name       date  season  avg_temp_c  min_temp_c  \
# 0       13588        0.0 2021-01-01     3.0         5.1         0.5
# 1       13588        0.0 2021-01-02     3.0         3.0        -2.6
# 2       13588        0.0 2021-01-03     3.0         6.8         3.5
# 3       13588        0.0 2021-01-04     3.0         6.6         6.1
# 4       13588        0.0 2021-01-05     3.0         4.3         2.3
#
#    max_temp_c  precipitation_mm  avg_wind_dir_deg  avg_wind_speed_kmh  \
# 0        13.2               0.0             330.0                 5.9
# 1        11.2               0.0             330.0                 5.9
# 2        12.5               1.3             339.0                 8.0
# 3         7.2               3.6             298.0                 5.3
# 4         6.7               4.6              11.0                 5.1
#
#    avg_sea_level_pres_hpa
# 0                  1021.2
# 1                  1021.2
# 2                  1017.8
# 3                  1011.3
# 4                  1014.5

# %%
plt.figure(figsize=(20, 20))
sns.heatmap(df.corr(), annot=True)
plt.show()

# %% [markdown]
# Remove the highly correlated features.

# %%
df = df.drop(columns=['station_id','city_name'])
#'max_temp_c','avg_temp_c','min_temp_c',

# %% [markdown]
# Encode the categorical features.

# %%
df.head()
# Out:
#         date  season  avg_temp_c  min_temp_c  max_temp_c  precipitation_mm  \
# 0 2021-01-01     3.0         5.1         0.5        13.2               0.0
# 1 2021-01-02     3.0         3.0        -2.6        11.2               0.0
# 2 2021-01-03     3.0         6.8         3.5        12.5               1.3
# 3 2021-01-04     3.0         6.6         6.1         7.2               3.6
# 4 2021-01-05     3.0         4.3         2.3         6.7               4.6
#
#    avg_wind_dir_deg  avg_wind_speed_kmh  avg_sea_level_pres_hpa
# 0             330.0                 5.9                  1021.2
# 1             330.0                 5.9                  1021.2
# 2             339.0                 8.0                  1017.8
# 3             298.0                 5.3                  1011.3
# 4              11.0                 5.1                  1014.5

# %% [markdown]
# # Feauture Extraction
# Select the relevant features for prediction and apply a lag of one, two, and three days to each chosen feature (except `season`), creating a set of features representing the meteorological conditions from the previous three days. To maintain dataset integrity, eliminate any resulting missing values at the beginning of the dataset.
#
# Hint: Use `df['column_name'].shift(period)`. Check the documentation at https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.shift.html.

# %%
features_to_shift = ['avg_temp_c','min_temp_c','max_temp_c','precipitation_mm', 'avg_wind_dir_deg', 'avg_wind_speed_kmh', 'avg_sea_level_pres_hpa']
for feature in features_to_shift:
    df[f'{feature}_shift_1'] = df[feature].shift(1)
    df[f'{feature}_shift_2'] = df[feature].shift(2)
    df[f'{feature}_shift_3'] = df[feature].shift(3)
df = df.dropna(axis=0, how='any')
df.head()
# Out:
#         date  season  avg_temp_c  min_temp_c  max_temp_c  precipitation_mm  \
# 3 2021-01-04     3.0         6.6         6.1         7.2               3.6
# 4 2021-01-05     3.0         4.3         2.3         6.7               4.6
# 5 2021-01-06     3.0         6.2         2.6        11.0               0.0
# 6 2021-01-07     3.0         7.3         4.1         9.3               0.5
# 7 2021-01-08     3.0         5.7         4.2         8.1               7.9
#
#    avg_wind_dir_deg  avg_wind_speed_kmh  avg_sea_level_pres_hpa  \
# 3             298.0                 5.3                  1011.3
# 4              11.0                 5.1                  1014.5
# 5              18.0                 6.7                  1017.2
# 6               0.0                 4.5                  1015.2
# 7             346.0                 6.5                  1009.7
#
#    avg_temp_c_shift_1  ...  precipitation_mm_shift_3  \
# 3                 6.8  ...                       0.0
# 4                 6.6  ...                       0.0
# 5                 4.3  ...                       1.3
# 6                 6.2  ...                       3.6
# 7                 7.3  ...                       4.6
#
#    avg_wind_dir_deg_shift_1  avg_wind_dir_deg_shift_2  \
# 3                     339.0                     330.0
# 4                     298.0                     339.0
# 5                      11.0                     298.0
# 6                      18.0                      11.0
# 7                       0.0                      18.0
#
#    avg_wind_dir_deg_shift_3  avg_wind_speed_kmh_shift_1  \
# 3                     330.0                         8.0
# 4                     330.0                         5.3
# 5                     339.0                         5.1
# 6                     298.0                         6.7
# 7                      11.0                         4.5
#
#    avg_wind_speed_kmh_shift_2  avg_wind_speed_kmh_shift_3  \
# 3                         5.9                         5.9
# 4                         8.0                         5.9
# 5                         5.3                         8.0
# 6                         5.1                         5.3
# 7                         6.7                         5.1
#
#    avg_sea_level_pres_hpa_shift_1  avg_sea_level_pres_hpa_shift_2  \
# 3                          1017.8                          1021.2
# 4                          1011.3                          1017.8
# 5                          1014.5                          1011.3
# 6                          1017.2                          1014.5
# 7                          1015.2                          1017.2
#
#    avg_sea_level_pres_hpa_shift_3
# 3                          1021.2
# 4                          1021.2
# 5                          1017.8
# 6                          1011.3
# 7                          1014.5
#
# [5 rows x 30 columns]

# %%
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month
df['day'] = df['date'].dt.day
df['day_of_week'] = df['date'].dt.dayofweek
df = df.drop(columns=['date'])

# %% [markdown]
# ## Dataset Splitting
# Partition the dataset into training and testing sets with an 80:20 ratio.
#
# **WARNING: DO NOT SHUFFLE THE DATASET.**

# %%
X = df.drop(columns='avg_sea_level_pres_hpa')
Y = df['avg_sea_level_pres_hpa']
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=42,shuffle=False)

# %% [markdown]
# ## Ensemble Learning Methods

# %% [markdown]
# ### Bagging

# %% [markdown]
# Create an instance of a Random Forest model and train it using the `fit` function.

# %% [markdown]
# Use the trained model to make predictions for the test set.

# %%
model1 = RandomForestRegressor(n_estimators=100, random_state=42)

# %%
df.head()
# Out:
#    season  avg_temp_c  min_temp_c  max_temp_c  precipitation_mm  \
# 3     3.0         6.6         6.1         7.2               3.6
# 4     3.0         4.3         2.3         6.7               4.6
# 5     3.0         6.2         2.6        11.0               0.0
# 6     3.0         7.3         4.1         9.3               0.5
# 7     3.0         5.7         4.2         8.1               7.9
#
#    avg_wind_dir_deg  avg_wind_speed_kmh  avg_sea_level_pres_hpa  \
# 3             298.0                 5.3                  1011.3
# 4              11.0                 5.1                  1014.5
# 5              18.0                 6.7                  1017.2
# 6               0.0                 4.5                  1015.2
# 7             346.0                 6.5                  1009.7
#
#    avg_temp_c_shift_1  avg_temp_c_shift_2  ...  avg_wind_speed_kmh_shift_1  \
# 3                 6.8                 3.0  ...                         8.0
# 4                 6.6                 6.8  ...                         5.3
# 5                 4.3                 6.6  ...                         5.1
# 6                 6.2                 4.3  ...                         6.7
# 7                 7.3                 6.2  ...                         4.5
#
#    avg_wind_speed_kmh_shift_2  avg_wind_speed_kmh_shift_3  \
# 3                         5.9                         5.9
# 4                         8.0                         5.9
# 5                         5.3                         8.0
# 6                         5.1                         5.3
# 7                         6.7                         5.1
#
#    avg_sea_level_pres_hpa_shift_1  avg_sea_level_pres_hpa_shift_2  \
# 3                          1017.8                          1021.2
# 4                          1011.3                          1017.8
# 5                          1014.5                          1011.3
# 6                          1017.2                          1014.5
# 7                          1015.2                          1017.2
#
#    avg_sea_level_pres_hpa_shift_3  year  month  day  day_of_week
# 3                          1021.2  2021      1    4            0
# 4                          1021.2  2021      1    5            1
# 5                          1017.8  2021      1    6            2
# 6                          1011.3  2021      1    7            3
# 7                          1014.5  2021      1    8            4
#
# [5 rows x 33 columns]

# %%
model1.fit(X_train,Y_train)
y_pred_1 = model1.predict(X_test)

# %%
print(f"R2 score for model1 is {r2_score(Y_test, y_pred_1)}")
# Out:
# R2 score for model1 is 0.720177647987028

# %% [markdown]
# Assess the performance of the model by using different metrics provided by the `scikit-learn` library.

# %%
print(f"Mean squared error is {mean_squared_error(Y_test, y_pred_1)}")
# Out:
# Mean squared error is 12.337061325797736

# %% [markdown]
# ### Boosting

# %% [markdown]
# Create an instance of an XGBoost model and train it using the `fit` function.

# %%
model2 = XGBRegressor(n_estimators=100, random_state=42,learning_rate=0.2)

# %% [markdown]
# Use the trained model to make predictions for the test set.

# %%
model2.fit(X_train,Y_train)
y_pred_2 = model2.predict(X_test)

# %% [markdown]
# Assess the performance of the model by using different metrics provided by the `scikit-learn` library.

# %%
print(f"R2 score for model1 is {r2_score(Y_test, y_pred_2)}")
# Out:
# R2 score for model1 is 0.7033504033772632

# %% [markdown]
# # Laboratory Exercise - Bonus Task (+ 2 points)

# %% [markdown]
# As part of the bonus task in this laboratory assignment, your objective is to fine-tune the max_depth (`max_depth`) for the Random Forest model using a cross-validation with grid search and time series split. This involves systematically experimenting with various values for `max_depth` and evaluating the model's performance using cross-validation. Upon determining the most suitable `max_depth` value, evaluate the model's performance on a test set for final assessment.
#
# Hints:
# - For grid search use the `GridCVSearch` from the `scikit-learn` library. Check the documentation at https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html.
# - For cross-validation use the `TimeSeriesSplit` from the `scikit-learn` library. Check the documentation at https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.TimeSeriesSplit.html.

# %% [markdown]
# ## Dataset Splitting
# Partition the dataset into training and testing sets with an 90:10 ratio.
#
# **WARNING: DO NOT SHUFFLE THE DATASET.**

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.1,random_state=42)

# %% [markdown]
# ## Fine-tuning the Random Forest Hyperparameter
# Experiment with various values for `max_depth` and evaluate the model's performance using cross-validation.

# %%
k_fold = KFold(n_splits=5)

# %%
param_grid ={        
    'max_depth': [3,5,7,10,15]
}

# %%
model3 = RandomForestRegressor(n_estimators=100)

# %%
cv = GridSearchCV(estimator=model3,param_grid=param_grid,cv=k_fold)
cv.fit(X_train,Y_train)
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=None, shuffle=False),
#              estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [3, 5, 7, 10, 15]})

# %% [markdown]
# ## Final Assessment of the Model Performance
# Upon determining the most suitable `max_depth` value, evaluate the model's performance on a test set for final assessment.

# %%
best_match = cv.best_estimator_
y_pred_3 = best_match.predict(X_test)
print(f"R2 score for model3 is {r2_score(Y_test, y_pred_3)}")
# Out:
# R2 score for model3 is 0.7311008120875533
